# %% [markdown]
# <a href="https://colab.research.google.com/github/TatiSilva26/Fonte-de-dados/blob/main/IceCream.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Análise de dados sobre o sorvete

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("sakshisatre/ice-cream-sales-dataset")

print("caminho para os arquivos e conjuntos de dados:", path)
# Out:
# caminho para os arquivos e conjuntos de dados: /root/.cache/kagglehub/datasets/sakshisatre/ice-cream-sales-dataset/versions/1

# %%
import pandas as pd

# Construct the full path to the CSV file
csv_path = path + "/Ice Cream.csv"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(csv_path)

# Display the first few rows of the DataFrame
display(df.head())
# Out:
#    Temperature  Revenue
# 0         24.6      535
# 1         26.1      626
# 2         27.8      661
# 3         20.6      488
# 4         11.6      317

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Create the scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Temperature', y='Revenue', data=df)

# Add the regression line
# We need the model and the original data (X) to predict values for the line
# Assuming 'model' and 'X' were created in a previous cell and are available
plt.plot(X, model.predict(X), color='red', linewidth=2)

plt.title('Venda vs Temperatura com regressão linear')
plt.xlabel('Temperatura (°C)')
plt.ylabel('Venda')
plt.grid(True)
plt.show()
